# %%
import pandas as pd
import os

# %%
file = "Ride_Data/2018_Q2_data.csv"
data = pd.read_csv(file)
data.head()
# Out:
#      Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  4/1/18                                              33148
# 1  4/2/18                                              22062
# 2  4/3/18                                              25883
# 3  4/4/18                                              36755
# 4  4/5/18                                              39814
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                        94040
# 1                                        50418
# 2                                        59477
# 3                                        80049
# 4                                        87382
#
#    Total Annual Members (All Time)  \
# 0                           257811
# 1                           257889
# 2                           257942
# 3                           258025
# 4                           258086
#
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# ...

# %% [markdown]
# ## Clean Trip Data 2018-04

# %%
file_trip = "Trip_Data/JC-201804-citibike-tripdata.csv"
trip_data = pd.read_csv(file_trip)
trip_data.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1814  2018-04-01 09:43:51.1590  2018-04-01 10:14:06.1300
# 1           298  2018-04-01 11:42:53.7090  2018-04-01 11:47:51.8770
# 2          1060  2018-04-01 12:43:11.9640  2018-04-01 13:00:52.8700
# 3          1035  2018-04-01 12:43:40.5890  2018-04-01 13:00:55.6620
# 4           559  2018-04-01 12:56:47.4600  2018-04-01 13:06:06.7710
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id    end station name  \
# 0               -74.033459            3638       Washington St
# ...

# %%
trip_data['Date'] = trip_data['starttime'].map(lambda x:x.split(" ")[0])
trip_data.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1814  2018-04-01 09:43:51.1590  2018-04-01 10:14:06.1300
# 1           298  2018-04-01 11:42:53.7090  2018-04-01 11:47:51.8770
# 2          1060  2018-04-01 12:43:11.9640  2018-04-01 13:00:52.8700
# 3          1035  2018-04-01 12:43:40.5890  2018-04-01 13:00:55.6620
# 4           559  2018-04-01 12:56:47.4600  2018-04-01 13:06:06.7710
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id    end station name  \
# 0               -74.033459            3638       Washington St
# ...

# %%
trip_data.to_csv("Clean_Data/Clean_Trip_Data/201804_tripdata.csv")

# %% [markdown]
# ## Clean Trip Data 2018-05

# %%
tripdata05 = "Trip_Data/JC-201805-citibike-tripdata.csv"
trip05_data = pd.read_csv(tripdata05)
trip05_data['Date'] = trip05_data['starttime'].map(lambda x:x.split(" ")[0])
trip05_data.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           131  2018-05-01 07:29:57.5490  2018-05-01 07:32:08.6160
# 1            73  2018-05-01 08:13:58.2560  2018-05-01 08:15:11.9230
# 2          4929  2018-05-01 08:17:21.3110  2018-05-01 09:39:31.0770
# 3           432  2018-05-01 08:25:58.7150  2018-05-01 08:33:10.8960
# 4           432  2018-05-01 08:28:09.9160  2018-05-01 08:35:22.1440
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3184      Paulus Hook
# ...

# %%
trip05_data.to_csv("Clean_Data/Clean_Trip_Data/201805_tripdata.csv")

# %% [markdown]
# ## Clean Trip Data 2018-06

# %%
tripdata06 = "Trip_Data/JC-201806-citibike-tripdata.csv"
trip06_data = pd.read_csv(tripdata06)
trip06_data['Date'] = trip06_data['starttime'].map(lambda x:x.split(" ")[0])
trip06_data.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           329  2018-06-01 07:07:00.2990  2018-06-01 07:12:30.2220
# 1           259  2018-06-01 08:24:43.8490  2018-06-01 08:29:03.8450
# 2           686  2018-06-01 09:17:49.5730  2018-06-01 09:29:16.1770
# 3           164  2018-06-01 09:44:00.4020  2018-06-01 09:46:44.6830
# 4           769  2018-06-01 09:59:28.7800  2018-06-01 10:12:18.6660
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3276  Marin Light Rail
# ...

# %%
trip06_data.to_csv("Clean_Data/Clean_Trip_Data/201806_tripdata.csv")

# %% [markdown]
# ## Clean Trip Data 2018-07

# %%
trip07_data = "Trip_Data/JC-201807-citibike-tripdata.csv"
trip07_data = pd.read_csv(trip07_data)
trip07_data['Date'] = trip07_data['starttime'].map(lambda x:x.split(" ")[0])
trip07_data.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1234  2018-07-01 02:08:39.8920  2018-07-01 02:29:14.4890
# 1          1041  2018-07-01 02:09:07.5180  2018-07-01 02:26:28.8720
# 2          2308  2018-07-01 02:14:45.7400  2018-07-01 02:53:14.5970
# 3           767  2018-07-01 02:25:12.4020  2018-07-01 02:38:00.0510
# 4           151  2018-07-01 04:07:44.0520  2018-07-01 04:10:15.8010
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3183   Exchange Place
# ...

# %%
trip07_data.to_csv("Clean_Data/Clean_Trip_Data/201807_tripdata.csv")

# %% [markdown]
# ## Clean Trip Data 2018-08

# %%
trip08_data = "Trip_Data/JC-201808-citibike-tripdata.csv"
trip08_data = pd.read_csv(trip08_data)
trip08_data['Date'] = trip08_data['starttime'].map(lambda x:x.split(" ")[0])
trip08_data.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           903  2018-08-01 06:40:33.3610  2018-08-01 06:55:37.1060
# 1            78  2018-08-01 08:21:00.1450  2018-08-01 08:22:18.6310
# 2           405  2018-08-01 08:43:52.5150  2018-08-01 08:50:37.6140
# 3           155  2018-08-01 09:48:24.9450  2018-08-01 09:51:00.9360
# 4           453  2018-08-01 12:15:35.1230  2018-08-01 12:23:08.8880
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3270  Jersey & 6th St
# ...

# %%
trip08_data.to_csv("Clean_Data/Clean_Trip_Data/201808_tripdata.csv")

# %% [markdown]
# ## Clean Trip Datat 2018-09

# %%
trip09_data = "Trip_Data/JC-201809-citibike-tripdata.csv"
trip09_data = pd.read_csv(trip09_data)
trip09_data['Date'] = trip09_data['starttime'].map(lambda x:x.split(" ")[0])
trip09_data.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           284  2018-09-01 01:48:22.0320  2018-09-01 01:53:06.9130
# 1           370  2018-09-01 01:48:22.5010  2018-09-01 01:54:32.9270
# 2          1181  2018-09-01 09:37:04.3070  2018-09-01 09:56:45.3280
# 3           383  2018-09-01 09:44:46.0030  2018-09-01 09:51:09.9230
# 4           377  2018-09-01 09:44:46.1850  2018-09-01 09:51:03.6330
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id    end station name  \
# 0               -74.033459            3267        Morris Canal
# ...

# %%
trip09_data.to_csv("Clean_Data/Clean_Trip_Data/201809_tripdata.csv")

# %% [markdown]
# ## Clean Trip Data 2018-10

# %%
trip10_data = "Trip_Data/JC-201810-citibike-tripdata.csv"
trip10_data = pd.read_csv(trip10_data)
trip10_data['Date'] = trip10_data['starttime'].map(lambda x:x.split(" ")[0])
trip10_data.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           152  2018-10-01 07:44:41.4170  2018-10-01 07:47:14.2960
# 1           122  2018-10-01 08:50:05.4340  2018-10-01 08:52:08.2250
# 2           211  2018-10-01 09:03:17.0640  2018-10-01 09:06:48.0940
# 3           342  2018-10-01 10:13:07.0090  2018-10-01 10:18:49.8960
# 4          2976  2018-10-01 10:45:14.2800  2018-10-01 11:34:51.2610
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3639        Harborside
# ...

# %%
trip10_data.to_csv("Clean_Data/Clean_Trip_Data/201810_tripdata.csv")

# %% [markdown]
# ## Clean Trip Data 2018-11

# %%
trip11_data = "Trip_Data/JC-201811-citibike-tripdata.csv"
trip11_data = pd.read_csv(trip11_data)
trip11_data['Date'] = trip11_data['starttime'].map(lambda x:x.split(" ")[0])
trip11_data.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1188  2018-11-01 06:32:27.5190  2018-11-01 06:52:15.9140
# 1           278  2018-11-01 07:14:31.8680  2018-11-01 07:19:10.2610
# 2           115  2018-11-01 07:33:17.1920  2018-11-01 07:35:12.2830
# 3           155  2018-11-01 08:20:10.9320  2018-11-01 08:22:46.7050
# 4            82  2018-11-01 08:35:02.7850  2018-11-01 08:36:25.1840
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3199     Newport Pkwy
# ...

# %%
trip11_data.to_csv("Clean_Data/Clean_Trip_Data/201811_tripdata.csv")

# %% [markdown]
# ## Clean Trip Data 2018-12

# %%
trip12_data = "Trip_Data/JC-201812-citibike-tripdata.csv"
trip12_data = pd.read_csv(trip12_data)
trip12_data['Date'] = trip12_data['starttime'].map(lambda x:x.split(" ")[0])
trip12_data.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           170  2018-12-01 00:03:53.3860  2018-12-01 00:06:43.7160
# 1           172  2018-12-01 00:47:13.7340  2018-12-01 00:50:05.8160
# 2           247  2018-12-01 00:48:57.6960  2018-12-01 00:53:05.6780
# 3           406  2018-12-01 01:33:53.6630  2018-12-01 01:40:39.7480
# 4           354  2018-12-01 06:26:52.5120  2018-12-01 06:32:46.5170
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3214  Essex Light Rail
# ...

# %%
trip12_data.to_csv("Clean_Data/Clean_Trip_Data/201812_tripdata.csv")

# %% [markdown]
# ## Clean Trip Data 2019-01

# %%
trip01_data = "Trip_Data/JC-201901-citibike-tripdata.csv"
trip01_data = pd.read_csv(trip01_data)
trip01_data['Date'] = trip01_data['starttime'].map(lambda x:x.split(" ")[0])
trip01_data.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1           505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2           756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3          1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4          1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id    end station name  \
# 0               -74.033459            3214    Essex Light Rail
# ...

# %%
trip01_data.to_csv("Clean_Data/Clean_Trip_Data/201901_tripdata.csv")

# %% [markdown]
# ## Clean Trip Data 2019-02

# %%
trip02_data = "Trip_Data/JC-201902-citibike-tripdata.csv"
trip02_data = pd.read_csv(trip02_data)
trip02_data['Date'] = trip02_data['starttime'].map(lambda x:x.split(" ")[0])
trip02_data.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           142  2019-02-01 15:35:02.0820  2019-02-01 15:37:24.1360
# 1           223  2019-02-01 17:00:46.8900  2019-02-01 17:04:30.5500
# 2           106  2019-02-01 17:08:01.3260  2019-02-01 17:09:47.4400
# 3           370  2019-02-01 17:09:31.2100  2019-02-01 17:15:41.6550
# 4           315  2019-02-01 17:19:53.2490  2019-02-01 17:25:09.1400
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3639       Harborside
# ...

# %%
trip02_data.to_csv("Clean_Data/Clean_Trip_Data/201902_tripdata.csv")

# %% [markdown]
# ## Clean Trip Data 2019-03

# %%
trip03_data = "Trip_Data/JC-201903-citibike-tripdata.csv"
trip03_data = pd.read_csv(trip03_data)
trip03_data['Date'] = trip03_data['starttime'].map(lambda x:x.split(" ")[0])
trip03_data.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           306  2019-03-01 06:47:08.2110  2019-03-01 06:52:14.7150
# 1           123  2019-03-01 07:30:53.0220  2019-03-01 07:32:56.7770
# 2           328  2019-03-01 08:18:30.4030  2019-03-01 08:23:59.0590
# 3            95  2019-03-01 11:04:47.2020  2019-03-01 11:06:22.8130
# 4           169  2019-03-01 11:51:29.4170  2019-03-01 11:54:19.2120
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3267     Morris Canal
# ...

# %%
trip03_data.to_csv("Clean_Data/Clean_Trip_Data/201903_tripdata.csv")

# %% [markdown]
# ## Clean Trip Data 2019-04

# %%
trip04_data = "Trip_Data/JC-201904-citibike-tripdata.csv"
trip04_data = pd.read_csv(trip04_data)
trip04_data['Date'] = trip04_data['starttime'].map(lambda x:x.split(" ")[0])
trip04_data.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           107  2019-04-01 07:48:04.7540  2019-04-01 07:49:52.3590
# 1           493  2019-04-01 12:41:09.6540  2019-04-01 12:49:23.0290
# 2           512  2019-04-01 14:27:07.9400  2019-04-01 14:35:40.9370
# 3           196  2019-04-01 15:07:38.1510  2019-04-01 15:10:54.6260
# 4           463  2019-04-01 16:19:24.6940  2019-04-01 16:27:08.6450
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3184       Paulus Hook
# ...

# %%
trip04_data.to_csv("Clean_Data/Clean_Trip_Data/201904_tripdata.csv")
